# %%
# Create a Python program that prompts the user to enter a temperature in Celsius, stores it in a variable, and then converts it to Fahrenheit using the formula (Celsius * 9/5) + 32. Display the result.

celsius = float(input("Enter temperature in celcius:"))
fahrenheit = (celsius *9/5) + 32
print("temperature in fahrenheit:",fahrenheit)
# Out:
# Enter temperature in celcius:45.3
# temperature in fahrenheit: 113.53999999999999

# %%
# Write a Python script that declares two string variables and concatenates them together. Prompt the user to enter their first name and last name separately, then concatenate them and print out the full name.

first_name = input("enter youe first name")
second_name = input("enter your second name")
full_name = first_name + " "  + second_name
print("full name :",full_name)
# Out:
# enter youe first nameanish
# enter your second namekumar
# full name : anish kumar

# %%
# Develop a Python program that calculates Body Mass Index (BMI). Prompt the user to enter their weight in kilograms and height in meters. Calculate BMI using the formula BMI = weight / (height * height). Print out the BMI.

weight = float(input("enter your weight in kilograms"))
height = float(input("enter your height in meters"))
bmi = weight / (height * height)
print("your bmi is :",bmi)
# Out:
# enter your weight in kilograms60
# enter your height in meters6
# your bmi is : 1.6666666666666667

# %%
# AGE CALCULATOR
birth_year = int(input("enter your birth year"))
current_year = 2025
age = current_year - birth_year
print("youe age is :",age)
# Out:
# enter your birth year2004
# youe age is : 21

# %%
# assignmenx  basic operation

x = 25
y = 5
print("Addition:", x + y)
print("Subtraction:", x - y)
print("Multiplication:", x * y)
print("Division:", x / y)
print("Floor Division:", x // y)
print("Modulus:", x % y)
print("Exponent:", x ** y)
# Out:
# Addition: 30
# Subtraction: 20
# Multiplication: 125
# Division: 5.0
# Floor Division: 5
# Modulus: 0
# Exponent: 9765625

# %%
# AREA OF TRIANGLE
base = float(input("enter the base of the triangle"))
height = float(input("enter the height of triangle "))
area = 0.5 * base * height
print("area of triangle is :",area)
# Out:
# enter the base of the triangle65
# enter the height of triangle 43
# area of triangle is : 1397.5

# %%
# even or odd
number = int(input("enter a number"))
if number % 2 == 0:
  print("number is even")
else:
  print("number is odd")
# Out:
# enter a number45
# number is odd

# %%
# grade calculator
math = int(input("enter mark for math(out of 100)"))
chem = int(input("enter mark for chem (out of 100)"))
phy  = int(input("enter mark for phy (out of 100)"))
total_marks = (math + phy + chem)
print("total_marks:",total_marks)
Percentage = (total_marks * 300) / 100
print("percentage :",Percentage)
if total_marks >= 90:
  print("grade :,A")
elif total_marks >= 80:
  print("grade :,B")
elif total_marks >= 70:
    print("grade :c")
elif total_marks >= 60:
  print("grade :D")
else:
    print("fail")
# Out:
# enter mark for math(out of 100)35
# enter mark for chem (out of 100)67
# enter mark for phy (out of 100)22
# total_marks: 124
# percentage : 372.0
# grade :,A

# %%
# -- input Section
# 1. Enter Student Name : Ravi
# 2. Enter Roll Number : RAVI009912
# 3. Enter Class : MCA
# 4. Enter JAVA Marks : 56
# 5. Enter C++ Marks : 89
# 6. Enter Python Marks : 12
# 7. Enter Ruby Marks : 56
# 8. Enter SQL Marks : 78

# -- Output Section
# Student Name : Ravi
# Roll Number : RAVI009912
# Class : MCA
# Enter JAVA Marks : 56/100
# C++ Marks : 89/100
# Python Marks : 12/100
# Ruby Marks : 56/100
# SQL Marks : 78/100
#    total = ?
#    Per % = ?%


Student_Name = str(input("enter Student Name"))
Roll_number = int(input("enter roll number"))
Class = str(input("enter class"))
java = int(input("enter java marks(out of 100)"))
c = int(input("enter c marks(out of 100)"))
python = int(input("enter python marks(out of 100)"))
ruby = int(input("enter ruby marks(out of 100)"))
sql = int(input("enter sql marks(out of 100)"))
total_marks = (java + c + ruby + python + sql)
print("total_marks :",total_marks)
Percentage = (total_marks * 500) / 100
print("percentage :",Percentage)
# Out:
# enter Student NameRicky
# enter roll number22354665
# enter classbtech
# enter java marks(out of 100)89
# enter c marks(out of 100)43
# enter python marks(out of 100)87
# enter ruby marks(out of 100)76
# enter sql marks(out of 100)40
# total_marks : 335
# percentage : 1675.0

# %%
# SIMPLE INTREST CALCULATION
principal = int(input("enter the principal amount"))
time = int(input("enter the time"))
rate = int(input("enter the rate of intrest"))
simple_interest = (principal * time * rate) / 100
print("simple intrest is :",simple_interest)
# Out:
# enter the principal amount350
# enter the time6
# enter the rate of intrest12
# simple intrest is : 252.0

# %%
# grade classifier task
score = int(input("enter your mark"))
if score >= 90:
  print("grade :A")
elif score >= 80:
  print("grade :B")
elif score >= 70:
  print("grade :C")
elif score >= 60:
  print("grade :D")
else:
  print("grade : fail")
# Out:
# enter your mark39
# grade : fail

# %%
# number comparision
num1 = int(input("enter first number"))
num2 = int(input("enter second number"))
if num1 > num2 :
  print("num1, is greater than" , num2)
elif num1 < num2:
  print("num2, is greater than", num1)
else:
  print("both number are equal")
# Out:
# enter first number34
# enter second number87
# num2, is greater than 34

# %%
# leap year
year = int(input("enter a year"))
if year % 4 == 0:
  print("year is a leap year")
else:
  print("year is not a leap year")
# Out:
# enter a year2078
# year is not a leap year

# %%
# Number sign Checker(+ve,-ve,zero)
number = int(input("enter a number"))
if number > 0:
  print("given number is positive")
elif number < 0:
 print("given number is negative")
else:
  print("equal with zero")
# Out:
# enter a number-7
# given number is negative

# %%
# vowel checker
word = str(input("enter a word"))
if word == "a":
  print("word is vowel")
elif word == "e":
  print("word is vowel")
elif word == "i":
  print("word is vowel")
elif word == "o":
  print("word is vowel")
elif word == "a":
  print("word is vowel")
else:
  print("not vowel")
# Out:
# enter a wordb
# not vowel

# %%
# AGE CLASSIFIER
age = int(input("enter your age"))
if age >= 18:
  print("you are eligible for vote")
else:
  print("you are not eligible for vote")
# Out:
# enter your age34
# you are eligible for vote

# %%
# EVEN OR ODD CHECKER
number = int(input("enter a number"))
if number % 2 == 0:
  print("given number is even number")
else:
  print("given no is odd number")
# Out:
# enter a number85
# given no is odd number

# %%
# TRIANGLE CLASSIFIER
side1 = int(input("enter first side"))
side2 = int(input("enter second side"))
side3  = int(input("enter third side"))
if side1 == side2 == side3:
  print("equilateral triangle")
elif side1 == side2 or side1 == side3 or side2 == side3:
  print("isosceles triangle")
else:
  print("scalene triangle")
# Out:
# enter first side4
# enter second side6
# enter third side4
# isosceles triangle

# %%
# TEMPERATURE ADVISER
temp = float(input("enter the current temp(in celsius)"))
if temp < 10:
  print("it is cold outside,you should wear a coat")
elif temp < 20:
  print("it is cool outside,you wear a jacket")
else:
  print("it is warm outside,you can wear a t_shirt")
# Out:
# enter the current temp(in celsius)30
# it is warm outside,you can wear a t_shirt

# %%
# NUMBER RANGE CHANGER
number = int(input("enter a number"))
if number <= 100:
  print("number is in the range of 1 to 100")
else:
  print("number is out of range")
# Out:
# enter a number560
# number is out of range

# %% [markdown]
# # New Section

# %%
# LOOP
# write a program to calculate sum of natural numbers
x = int(input("enter a number"))
for i in range(1,x+1):
  sum_of_numbers = 0
  sum_of_numbers += i
print("the sum of natural numbers up to",x,"is:",sum_of_numbers)
# Out:
# enter a number23
# the sum of natural numbers up to 23 is: 23

# %%
# GENERATE MULTIPLICATION TABLE
number = int(input("enter a number"))
for i in range(1,11):
  print(number*i)
  print(number,"x",i,"==",number*1)
# Out:
# enter a number6
# 6
# 6 x 1 == 6
# 12
# 6 x 2 == 6
# 18
# 6 x 3 == 6
# 24
# 6 x 4 == 6
# 30
# 6 x 5 == 6
# 36
# 6 x 6 == 6
# 42
# 6 x 7 == 6
# 48
# 6 x 8 == 6
# 54
# 6 x 9 == 6
# 60
# 6 x 10 == 6

# %%
# REVERSE NUMBER
number = int(input("enter a number"))
reverse = 0
while number > 0:
  digit = number % 10
  reverse = reverse * 10 + digit
  number //= 10
print("reverse number is :",reverse)
# Out:
# enter a number879
# reverse number is : 978

# %%
# write a program to display count of alphabets in to string
word = "have a good day"
count = 0
for char in word:
  count += 1
  print("count of alphabets in string is :",count)
# Out:
# count of alphabets in string is : 1
# count of alphabets in string is : 2
# count of alphabets in string is : 3
# count of alphabets in string is : 4
# count of alphabets in string is : 5
# count of alphabets in string is : 6
# count of alphabets in string is : 7
# count of alphabets in string is : 8
# count of alphabets in string is : 9
# count of alphabets in string is : 10
# count of alphabets in string is : 11
# count of alphabets in string is : 12
# count of alphabets in string is : 13
# count of alphabets in string is : 14
# count of alphabets in string is : 15

# %%
# LIST ITERATION
fruits = ["apple","banana","cherry","water melon","kiwi","papeya"]
print(fruits)
for fruit in fruits:
  print(fruit)
# Out:
# ['apple', 'banana', 'cherry', 'water melon', 'kiwi', 'papeya']
# apple
# banana
# cherry
# water melon
# kiwi
# papeya

# %%
# Write a program that takes an integer as input and prints a countdown from that number to 1 using a while loop.
number = int(input("enter a number :"))
while number >= 1:
     print(number)
number -= 1
# Out:
# Streaming output truncated to the last 5000 lines.
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# ...

# %%
# sum function

def add(a,b):
  print(a + b)

add(89,6)
add(56,8)
# Out:
# 95
# 64

# %%
# FACTORIAL FUNCTION

number = int(input("enter a number"))
calculated_factorial = 1
for i in range(1,number+1):
 calculated_factorial *= i
print("calculated_factorial of",number,"is",calculated_factorial)
# Out:
# enter a number6
# calculated_factorial of 6 is 720

# %%
# LIST
favorite_colors =["red","yellow","green","pink","gery"]
print( favorite_colors)

def print_colors(colors_list):
  for color in colors_list:
    print(color)

print_colors(favorite_colors)
# Out:
# ['red', 'yellow', 'green', 'pink', 'gery']
# red
# yellow
# green
# pink
# gery

# %%
# prompt: Create a list of numbers.
# Write a function named square_numbers that takes a list as a parameter and returns a new list containing the squares of each number.
# Call the function with your list and print the results.

def square_numbers(numbers_list):
  squared_numbers = []
  for number in numbers_list:
    squared_numbers.append(number**2)
  return squared_numbers

numbers = [1, 2, 3, 4, 5]
squared_numbers_list = square_numbers(numbers)
squared_numbers_list
